# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None


df = pd.read_csv(r'/Users/matthewmarron/Desktop/Data Analytics /Portfolio Projects/python/Movies/movies.csv')

# %%
df = df.dropna()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.      146
# 1   58853106   Columbia Pictures      104
# 2  538375067           Lucasfilm      124
# 3   83453539  Paramount Pictures       88
# 4   39846344      Orion Pictures       98

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.      146
# 1   58853106   Columbia Pictures      104
# 2  538375067           Lucasfilm      124
# 3   83453539  Paramount Pictures       88
# 4   39846344      Orion Pictures       98

# %%
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

df

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.      146
# 1   58853106   Columbia Pictures      104
# 2  538375067           Lucasfilm      124
# 3   83453539  Paramount Pictures       88
# 4   39846344      Orion Pictures       98

# %%
pd.set_option('display.max_rows', None)

# %%
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Budget for Film ')

plt.ylabel('Gross Earnings')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime  yearcorrect
# 0   46998772        Warner Bros.      146         1980
# 1   58853106   Columbia Pictures      104         1980
# 2  538375067           Lucasfilm      124         1980
# 3   83453539  Paramount Pictures       88         1980
# 4   39846344      Orion Pictures       98         1980

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.049104  0.185708  0.295467  0.261298  0.071405
# score        0.049104  1.000000  0.473939  0.067766  0.215015  0.415607
# votes        0.185708  0.473939  1.000000  0.444236  0.616558  0.364047
# budget       0.295467  0.067766  0.444236  1.000000  0.743603  0.327926
# gross        0.261298  0.215015  0.616558  0.743603  1.000000  0.286038
# runtime      0.071405  0.415607  0.364047  0.327926  0.286038  1.000000
# yearcorrect  0.998488  0.054536  0.182200  0.287409  0.255039  0.071293
#
#              yearcorrect
# year            0.998488
# score           0.054536
# votes           0.182200
# budget          0.287409
# gross           0.255039
# runtime         0.071293
# yearcorrect     1.000000

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  3239       5      6  1980      1077    8.4   927000      1468    2154
# 1  2704       5      1  1980       933    5.8    65000      1279     877
# 2  2501       3      0  1980      1124    8.7  1200000       608    1377
# 3   145       3      4  1980       933    7.7   221000       713    1065
# 4   517       5      4  1980       970    7.3   108000       580     263
#
#    star  country    budget      gross  company  runtime
# 0   539       43  19000000   46998772     1099      146
# 1   171       44   4500000   58853106      342      104
# 2   912       44  18000000  538375067      723      124
# 3  1164       44   3500000   83453539      848       88
# 4   216       44   6000000   39846344      830       98

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.      146
# 1   58853106   Columbia Pictures      104
# 2  538375067           Lucasfilm      124
# 3   83453539  Paramount Pictures       88
# 4   39846344      Orion Pictures       98

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                  year  released     score     votes  director    writer  \
# year         1.000000 -0.000303  0.049104  0.185708 -0.042615 -0.035416
# released    -0.000303  1.000000  0.031227  0.026862  0.005795  0.000488
# score        0.049104  0.031227  1.000000  0.473939 -0.003779 -0.001063
# votes        0.185708  0.026862  0.473939  1.000000 -0.036815 -0.024892
# director    -0.042615  0.005795 -0.003779 -0.036815  1.000000  0.266053
# writer      -0.035416  0.000488 -0.001063 -0.024892  0.266053  1.000000
# star        -0.038880  0.006216 -0.002831 -0.031654  0.031244  0.017050
# country     -0.067279 -0.021807 -0.039090  0.041639  0.013409  0.022370
# budget       0.295467  0.032496  0.067766  0.444236 -0.024060 -0.045869
# gross        0.261298  0.005144  0.215015  0.616558 -0.052879 -0.045757
# company     -0.012522 -0.006972  0.044385  0.131404 -0.020544 -0.002080
# runtime      0.071405  0.025009  0.415607  0.364047  0.000467 -0.019114
# yearcorrect  0.998488 -0.005173  0.054536  0.182200 -0.042755 -0.035364
#
#                  star   country    budget     gross   company   runtime  \
# year        -0.038880 -0.067279  0.295467  0.261298 -0.012522  0.071405
# released     0.006216 -0.021807  0.032496  0.005144 -0.006972  0.025009
# score       -0.002831 -0.039090  0.067766  0.215015  0.044385  0.415607
# votes       -0.031654  0.041639  0.444236  0.616558  0.131404  0.364047
# director     0.031244  0.013409 -0.024060 -0.052879 -0.020544  0.000467
# writer       0.017050  0.022370 -0.045869 -0.045757 -0.002080 -0.019114
# star         1.000000 -0.013997 -0.025518 -0.004263  0.016012 -0.004753
# country     -0.013997  1.000000  0.057905  0.066411  0.039967 -0.035122
# budget      -0.025518  0.057905  1.000000  0.743603  0.184637  0.327926
# gross       -0.004263  0.066411  0.743603  1.000000  0.150875  0.286038
# company      0.016012  0.039967  0.184637  0.150875  1.000000  0.058251
# runtime     -0.004753 -0.035122  0.327926  0.286038  0.058251  1.000000
# yearcorrect -0.039049 -0.074799  0.287409  0.255039 -0.017286  0.071293
#
#              yearcorrect
# year            0.998488
# released       -0.005173
# score           0.054536
# votes           0.182200
# director       -0.042755
# writer         -0.035364
# star           -0.039049
# country        -0.074799
# budget          0.287409
# gross           0.255039
# company        -0.017286
# runtime         0.071293
# yearcorrect     1.000000

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.041023
#       genre       0.035808
#       year        0.033953
#       released   -0.017980
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head()
# Out:
# genre   budget   -0.386742
# budget  genre    -0.386742
# gross   genre    -0.259817
# genre   gross    -0.259817
# rating  budget   -0.210444
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes        gross          0.616558
# gross        votes          0.616558
#              budget         0.743603
# budget       gross          0.743603
# yearcorrect  year           0.998488
# year         yearcorrect    0.998488
#              year           1.000000
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings

# Company has low correlation
